# %%
import rope.base.project
from rope.refactor.move import MoveGlobal

# %%
myproject = rope.base.project.Project('../../sweepai')

myresource = myproject.get_resource('handlers/on_ticket.py')
func_def = "center("
offset = myresource.read().find(func_def)
print(offset)

mover = MoveGlobal(myproject, myresource, offset)
change_set = mover.get_changes("utils.ticket_utils")
for change in change_set.changes:
    print(change.get_description())
# myproject.do(change_set)
# Out:
# 3024
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 12
#       9 change_set = mover.get_changes("utils.ticket_utils")
#      10 # for change in change_set.changes:
#      11 #     print(change.get_description())
# ---> 12 myproject.do(change_set)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/project.py:119, in _Project.do(self, changes, task_handle)
#     113 def do(self, changes, task_handle=taskhandle.DEFAULT_TASK_HANDLE):
#     114     """Apply the changes in a `ChangeSet`
#     115
#     116     Most of the time you call this function for committing the
#     117     changes for a refactoring.
#     118     """
# --> 119     self.history.do(changes, task_handle=task_handle)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/history.py:35, in History.do(self, changes, task_handle)
#      33 try:
#      34     self.current_change = changes
# ---> 35     changes.do(change.create_job_set(task_handle, changes))
#      36 finally:
#      37     self.current_change = None
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/change.py:67, in ChangeSet.do(self, job_set)
#      65 done = []
#      66 for change in self.changes:
# ---> 67     change.do(job_set)
#      68     done.append(change)
#      69 self.time = time.time()
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/change.py:128, in _handle_job_set.<locals>.call(self, job_set)
#     126 def call(self, job_set=taskhandle.DEFAULT_JOB_SET):
#     127     job_set.started_job(str(self))
# --> 128     function(self)
#     129     job_set.finished_job()
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/change.py:153, in ChangeContents.do(self)
#     151 if self.old_contents is None:
#     152     self.old_contents = self.resource.read()
# --> 153 self._operations.write_file(self.resource, self.new_contents)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/change.py:346, in _ResourceOperations.write_file(self, resource, contents)
#     344 fscommands.write(resource.real_path, data)
#     345 for observer in list(self.project.observers):
# --> 346     observer.resource_changed(resource)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/resourceobserver.py:31, in ResourceObserver.resource_changed(self, resource)
#      29 """It is called when the resource changes"""
#      30 if self.changed is not None:
# ---> 31     self.changed(resource)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pycore.py:58, in PyCore._file_changed_for_soa(self, resource, new_resource)
#      56 old_contents = self.project.history.contents_before_current_change(resource)
#      57 if old_contents is not None:
# ---> 58     perform_soa_on_changed_scopes(self.project, resource, old_contents)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pycore.py:307, in perform_soa_on_changed_scopes(project, resource, old_contents)
#     304     end = scope.get_end()
#     305     return detector.consume_changes(start, end)
# --> 307 pycore.analyze_module(resource, should_analyze, search_subscopes)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pycore.py:207, in PyCore.analyze_module(self, resource, should_analyze, search_subscopes, followed_calls)
#     205 pymodule = self.resource_to_pyobject(resource)
#     206 self.module_cache.forget_all_data()
# --> 207 rope.base.oi.soa.analyze_module(
#     208     self, pymodule, should_analyze, search_subscopes, followed_calls
#     209 )
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/oi/soa.py:14, in analyze_module(pycore, pymodule, should_analyze, search_subscopes, followed_calls)
#       7 def analyze_module(pycore, pymodule, should_analyze, search_subscopes, followed_calls):
#       8     """Analyze `pymodule` for static object inference
#       9
#      10     Analyzes scopes for collecting object information.  The analysis
#      11     starts from inner scopes.
#      12
#      13     """
# ---> 14     _analyze_node(pycore, pymodule, should_analyze, search_subscopes, followed_calls)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/oi/soa.py:20, in _analyze_node(pycore, pydefined, should_analyze, search_subscopes, followed_calls)
#      18 if search_subscopes(pydefined):
#      19     for scope in pydefined.get_scope().get_scopes():
# ---> 20         _analyze_node(
#      21             pycore, scope.pyobject, should_analyze, search_subscopes, followed_calls
#      22         )
#      23 if should_analyze(pydefined):
#      24     new_followed_calls = max(0, followed_calls - 1)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/oi/soa.py:35, in _analyze_node(pycore, pydefined, should_analyze, search_subscopes, followed_calls)
#      33 visitor = SOAVisitor(pycore, pydefined, _follow if followed_calls else None)
#      34 for child in rope.base.ast.iter_child_nodes(pydefined.get_ast()):
# ---> 35     visitor.visit(child)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/ast.py:66, in RopeNodeVisitor.visit(self, node)
#      64 method = "_" + node.__class__.__name__
#      65 visitor = getattr(self, method, self.generic_visit)
# ---> 66 return visitor(node)
#
# File /usr/lib/python3.10/ast.py:426, in NodeVisitor.generic_visit(self, node)
#     424     for item in value:
#     425         if isinstance(item, AST):
# --> 426             self.visit(item)
#     427 elif isinstance(value, AST):
#     428     self.visit(value)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/ast.py:66, in RopeNodeVisitor.visit(self, node)
#      64 method = "_" + node.__class__.__name__
#      65 visitor = getattr(self, method, self.generic_visit)
# ---> 66 return visitor(node)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/oi/soa.py:112, in SOAVisitor._Assign(self, node)
#     110 def _Assign(self, node):
#     111     for child in rope.base.ast.iter_child_nodes(node):
# --> 112         self.visit(child)
#     113     visitor = _SOAAssignVisitor()
#     114     nodes = []
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/ast.py:66, in RopeNodeVisitor.visit(self, node)
#      64 method = "_" + node.__class__.__name__
#      65 visitor = getattr(self, method, self.generic_visit)
# ---> 66 return visitor(node)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/oi/soa.py:71, in SOAVisitor._Call(self, node)
#      69 else:
#      70     return
# ---> 71 self._call(pyfunction, args)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/oi/soa.py:82, in SOAVisitor._call(self, pyfunction, args)
#      79 if self.follow is not None:
#      80     before = self._parameter_objects(pyfunction)
#      81 self.pycore.object_info.function_called(
# ---> 82     pyfunction, args.get_arguments(pyfunction.get_param_names())
#      83 )
#      84 pyfunction._set_parameter_pyobjects(None)
#      85 if self.follow is not None:
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/arguments.py:20, in Arguments.get_arguments(self, parameters)
#      18 def get_arguments(self, parameters):
#      19     result = []
# ---> 20     for pyname in self.get_pynames(parameters):
#      21         if pyname is None:
#      22             result.append(None)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/arguments.py:31, in Arguments.get_pynames(self, parameters)
#      29 for index, arg in enumerate(self.args):
#      30     if isinstance(arg, ast.keyword) and arg.arg in parameters:
# ---> 31         result[parameters.index(arg.arg)] = self._evaluate(arg.value)
#      32     else:
#      33         result[index] = self._evaluate(arg)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/arguments.py:41, in Arguments._evaluate(self, ast_node)
#      40 def _evaluate(self, ast_node):
# ---> 41     return rope.base.evaluate.eval_node(self.scope, ast_node)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/evaluate.py:36, in eval_node(scope, node)
#      31 def eval_node(scope, node):
#      32     """Evaluate a `ast.AST` node and return a PyName
#      33
#      34     Return `None` if the expression cannot be evaluated.
#      35     """
# ---> 36     return eval_node2(scope, node)[1]
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/evaluate.py:41, in eval_node2(scope, node)
#      39 def eval_node2(scope, node):
#      40     evaluator = StatementEvaluator(scope)
# ---> 41     evaluator.visit(node)
#      42     return evaluator.old_result, evaluator.result
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/ast.py:66, in RopeNodeVisitor.visit(self, node)
#      64 method = "_" + node.__class__.__name__
#      65 visitor = getattr(self, method, self.generic_visit)
# ---> 66 return visitor(node)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/evaluate.py:206, in StatementEvaluator._Call(self, node)
#     203     pyfunction = pyobject["__call__"].get_object()
#     204 if pyfunction is not None:
#     205     self.result = rope.base.pynames.UnboundName(
# --> 206         pyobject=_get_returned(pyfunction)
#     207     )
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/evaluate.py:187, in StatementEvaluator._Call.<locals>._get_returned(pyobject)
#     185 def _get_returned(pyobject):
#     186     args = arguments.create_arguments(primary, pyobject, node, self.scope)
# --> 187     return pyobject.get_returned_object(args)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pyobjectsdef.py:73, in PyFunction.get_returned_object(self, args)
#      72 def get_returned_object(self, args):
# ---> 73     return self.returned.get(args)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/utils/__init__.py:32, in prevent_recursion.<locals>.decorator.<locals>.newfunc(self, *args, **kwds)
#      30 setattr(self, name, True)
#      31 try:
# ---> 32     return func(self, *args, **kwds)
#      33 finally:
#      34     setattr(self, name, False)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pynames.py:208, in _Inferred.get(self, *args, **kwds)
#     205 @utils.prevent_recursion(_circular_inference)
#     206 def get(self, *args, **kwds):
#     207     if self.concluded is None or self.concluded.get() is None:
# --> 208         self.set(self.get_inferred(*args, **kwds))
#     209     if self._get() is None:
#     210         self.set(rope.base.pyobjects.get_unknown())
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pyobjectsdef.py:45, in PyFunction._infer_returned(self, args)
#      44 def _infer_returned(self, args=None):
# ---> 45     return rope.base.oi.soi.infer_returned_object(self, args)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/utils/__init__.py:47, in ignore_exception.<locals>._decorator.<locals>.newfunc(*args, **kwds)
#      45 def newfunc(*args, **kwds):
#      46     try:
# ---> 47         return func(*args, **kwds)
#      48     except exception_class:
#      49         pass
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/oi/soi.py:21, in infer_returned_object(pyfunction, args)
#      19 if result is not None:
#      20     return result
# ---> 21 result = _infer_returned(pyfunction, args)
#      22 if result is not None:
#      23     if args and pyfunction.get_module().get_resource() is not None:
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/oi/soi.py:114, in _infer_returned(pyobject, args)
#     112 if resulting_pyname is None:
#     113     continue
# --> 114 pyobject = resulting_pyname.get_object()
#     115 if pyobject == pyobjects.get_unknown():
#     116     continue
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pynamesdef.py:28, in AssignedName.get_object(self)
#      27 def get_object(self):
# ---> 28     return self.pyobject.get()
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/utils/__init__.py:32, in prevent_recursion.<locals>.decorator.<locals>.newfunc(self, *args, **kwds)
#      30 setattr(self, name, True)
#      31 try:
# ---> 32     return func(self, *args, **kwds)
#      33 finally:
#      34     setattr(self, name, False)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pynames.py:208, in _Inferred.get(self, *args, **kwds)
#     205 @utils.prevent_recursion(_circular_inference)
#     206 def get(self, *args, **kwds):
#     207     if self.concluded is None or self.concluded.get() is None:
# --> 208         self.set(self.get_inferred(*args, **kwds))
#     209     if self._get() is None:
#     210         self.set(rope.base.pyobjects.get_unknown())
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/utils/__init__.py:32, in prevent_recursion.<locals>.decorator.<locals>.newfunc(self, *args, **kwds)
#      30 setattr(self, name, True)
#      31 try:
# ---> 32     return func(self, *args, **kwds)
#      33 finally:
#      34     setattr(self, name, False)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pynamesdef.py:25, in AssignedName._get_inferred(self)
#      22 @utils.prevent_recursion(lambda: None)
#      23 def _get_inferred(self):
#      24     if self.module is not None:
# ---> 25         return rope.base.oi.soi.infer_assigned_object(self)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/utils/__init__.py:47, in ignore_exception.<locals>._decorator.<locals>.newfunc(*args, **kwds)
#      45 def newfunc(*args, **kwds):
#      46     try:
# ---> 47         return func(*args, **kwds)
#      48     except exception_class:
#      49         pass
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/oi/soi.py:66, in infer_assigned_object(pyname)
#      64     return
#      65 for assignment in reversed(pyname.assignments):
# ---> 66     result = _infer_assignment(assignment, pyname.module)
#      67     if (
#      68         isinstance(result, rope.base.builtins.BuiltinUnknown)
#      69         and result.get_name() == "NotImplementedType"
#      70     ):
#      71         break
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/utils/__init__.py:47, in ignore_exception.<locals>._decorator.<locals>.newfunc(*args, **kwds)
#      45 def newfunc(*args, **kwds):
#      46     try:
# ---> 47         return func(*args, **kwds)
#      48     except exception_class:
#      49         pass
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/oi/soi.py:143, in _infer_assignment(assignment, pymodule)
#     141 @_ignore_inferred
#     142 def _infer_assignment(assignment, pymodule):
# --> 143     result = _follow_pyname(assignment, pymodule)
#     144     if result is None:
#     145         return None
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/utils/__init__.py:47, in ignore_exception.<locals>._decorator.<locals>.newfunc(*args, **kwds)
#      45 def newfunc(*args, **kwds):
#      46     try:
# ---> 47         return func(*args, **kwds)
#      48     except exception_class:
#      49         pass
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/oi/soi.py:176, in _follow_pyname(assignment, pymodule, lineno)
#     174     lineno = _get_lineno_for_node(assign_node)
#     175 holding_scope = pymodule.get_scope().get_inner_scope_for_line(lineno)
# --> 176 pyname = evaluate.eval_node(holding_scope, assign_node)
#     177 if pyname is not None:
#     178     result = pyname.get_object()
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/evaluate.py:36, in eval_node(scope, node)
#      31 def eval_node(scope, node):
#      32     """Evaluate a `ast.AST` node and return a PyName
#      33
#      34     Return `None` if the expression cannot be evaluated.
#      35     """
# ---> 36     return eval_node2(scope, node)[1]
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/evaluate.py:41, in eval_node2(scope, node)
#      39 def eval_node2(scope, node):
#      40     evaluator = StatementEvaluator(scope)
# ---> 41     evaluator.visit(node)
#      42     return evaluator.old_result, evaluator.result
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/ast.py:66, in RopeNodeVisitor.visit(self, node)
#      64 method = "_" + node.__class__.__name__
#      65 visitor = getattr(self, method, self.generic_visit)
# ---> 66 return visitor(node)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/evaluate.py:335, in StatementEvaluator._Subscript(self, node)
#     333     self._call_function(node.value, "__getitem__", [node.slice])
#     334 elif isinstance(node.slice, ast.expr):
# --> 335     self._call_function(node.value, "__getitem__", [node.value])
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/evaluate.py:343, in StatementEvaluator._call_function(self, node, function_name, other_args)
#     341 pyname = eval_node(self.scope, node)
#     342 if pyname is not None:
# --> 343     pyobject = pyname.get_object()
#     344 else:
#     345     return
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pynamesdef.py:28, in AssignedName.get_object(self)
#      27 def get_object(self):
# ---> 28     return self.pyobject.get()
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/utils/__init__.py:32, in prevent_recursion.<locals>.decorator.<locals>.newfunc(self, *args, **kwds)
#      30 setattr(self, name, True)
#      31 try:
# ---> 32     return func(self, *args, **kwds)
#      33 finally:
#      34     setattr(self, name, False)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pynames.py:208, in _Inferred.get(self, *args, **kwds)
#     205 @utils.prevent_recursion(_circular_inference)
#     206 def get(self, *args, **kwds):
#     207     if self.concluded is None or self.concluded.get() is None:
# --> 208         self.set(self.get_inferred(*args, **kwds))
#     209     if self._get() is None:
#     210         self.set(rope.base.pyobjects.get_unknown())
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/utils/__init__.py:32, in prevent_recursion.<locals>.decorator.<locals>.newfunc(self, *args, **kwds)
#      30 setattr(self, name, True)
#      31 try:
# ---> 32     return func(self, *args, **kwds)
#      33 finally:
#      34     setattr(self, name, False)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pynamesdef.py:25, in AssignedName._get_inferred(self)
#      22 @utils.prevent_recursion(lambda: None)
#      23 def _get_inferred(self):
#      24     if self.module is not None:
# ---> 25         return rope.base.oi.soi.infer_assigned_object(self)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/utils/__init__.py:47, in ignore_exception.<locals>._decorator.<locals>.newfunc(*args, **kwds)
#      45 def newfunc(*args, **kwds):
#      46     try:
# ---> 47         return func(*args, **kwds)
#      48     except exception_class:
#      49         pass
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/oi/soi.py:66, in infer_assigned_object(pyname)
#      64     return
#      65 for assignment in reversed(pyname.assignments):
# ---> 66     result = _infer_assignment(assignment, pyname.module)
#      67     if (
#      68         isinstance(result, rope.base.builtins.BuiltinUnknown)
#      69         and result.get_name() == "NotImplementedType"
#      70     ):
#      71         break
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/utils/__init__.py:47, in ignore_exception.<locals>._decorator.<locals>.newfunc(*args, **kwds)
#      45 def newfunc(*args, **kwds):
#      46     try:
# ---> 47         return func(*args, **kwds)
#      48     except exception_class:
#      49         pass
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/oi/soi.py:143, in _infer_assignment(assignment, pymodule)
#     141 @_ignore_inferred
#     142 def _infer_assignment(assignment, pymodule):
# --> 143     result = _follow_pyname(assignment, pymodule)
#     144     if result is None:
#     145         return None
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/utils/__init__.py:47, in ignore_exception.<locals>._decorator.<locals>.newfunc(*args, **kwds)
#      45 def newfunc(*args, **kwds):
#      46     try:
# ---> 47         return func(*args, **kwds)
#      48     except exception_class:
#      49         pass
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/oi/soi.py:176, in _follow_pyname(assignment, pymodule, lineno)
#     174     lineno = _get_lineno_for_node(assign_node)
#     175 holding_scope = pymodule.get_scope().get_inner_scope_for_line(lineno)
# --> 176 pyname = evaluate.eval_node(holding_scope, assign_node)
#     177 if pyname is not None:
#     178     result = pyname.get_object()
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/evaluate.py:36, in eval_node(scope, node)
#      31 def eval_node(scope, node):
#      32     """Evaluate a `ast.AST` node and return a PyName
#      33
#      34     Return `None` if the expression cannot be evaluated.
#      35     """
# ---> 36     return eval_node2(scope, node)[1]
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/evaluate.py:41, in eval_node2(scope, node)
#      39 def eval_node2(scope, node):
#      40     evaluator = StatementEvaluator(scope)
# ---> 41     evaluator.visit(node)
#      42     return evaluator.old_result, evaluator.result
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/ast.py:66, in RopeNodeVisitor.visit(self, node)
#      64 method = "_" + node.__class__.__name__
#      65 visitor = getattr(self, method, self.generic_visit)
# ---> 66 return visitor(node)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/evaluate.py:181, in StatementEvaluator._Call(self, node)
#     180 def _Call(self, node):
# --> 181     primary, pyobject = self._get_primary_and_object_for_node(node.func)
#     182     if pyobject is None:
#     183         return
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/evaluate.py:323, in StatementEvaluator._get_primary_and_object_for_node(self, stmt)
#     322 def _get_primary_and_object_for_node(self, stmt):
# --> 323     primary, pyname = eval_node2(self.scope, stmt)
#     324     pyobject = None
#     325     if pyname is not None:
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/evaluate.py:41, in eval_node2(scope, node)
#      39 def eval_node2(scope, node):
#      40     evaluator = StatementEvaluator(scope)
# ---> 41     evaluator.visit(node)
#      42     return evaluator.old_result, evaluator.result
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/ast.py:66, in RopeNodeVisitor.visit(self, node)
#      64 method = "_" + node.__class__.__name__
#      65 visitor = getattr(self, method, self.generic_visit)
# ---> 66 return visitor(node)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/evaluate.py:176, in StatementEvaluator._Attribute(self, node)
#     174 if pyname.get_object() != rope.base.pyobjects.get_unknown():
#     175     try:
# --> 176         self.result = pyname.get_object()[node.attr]
#     177     except exceptions.AttributeNotFoundError:
#     178         self.result = None
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pyobjects.py:30, in PyObject.__getitem__(self, key)
#      28 def __getitem__(self, key):
#      29     """The same as ``get_attribute(key)``"""
# ---> 30     return self.get_attribute(key)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pyobjects.py:216, in PyDefinedObject.get_attribute(self, name)
#     214 if name in self._get_structural_attributes():
#     215     return self._get_structural_attributes()[name]
# --> 216 if name in self._get_concluded_attributes():
#     217     return self._get_concluded_attributes()[name]
#     218 raise exceptions.AttributeNotFoundError("Attribute %s not found" % name)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/utils/__init__.py:32, in prevent_recursion.<locals>.decorator.<locals>.newfunc(self, *args, **kwds)
#      30 setattr(self, name, True)
#      31 try:
# ---> 32     return func(self, *args, **kwds)
#      33 finally:
#      34     setattr(self, name, False)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pyobjects.py:203, in PyDefinedObject._get_concluded_attributes(self)
#     201 if self.concluded_attributes.get() is None:
#     202     self._get_structural_attributes()
# --> 203     self.concluded_attributes.set(self._create_concluded_attributes())
#     204 return self.concluded_attributes.get()
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pyobjectsdef.py:262, in PyPackage._create_concluded_attributes(self)
#     260 if init_dot_py:
#     261     init_object = self.pycore.project.get_pymodule(init_dot_py)
# --> 262     result.update(init_object.get_attributes())
#     263 return result
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pyobjects.py:208, in PyDefinedObject.get_attributes(self)
#     206 def get_attributes(self):
#     207     if self.attributes.get() is None:
# --> 208         result = dict(self._get_concluded_attributes())
#     209         result.update(self._get_structural_attributes())
#     210         self.attributes.set(result)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/utils/__init__.py:32, in prevent_recursion.<locals>.decorator.<locals>.newfunc(self, *args, **kwds)
#      30 setattr(self, name, True)
#      31 try:
# ---> 32     return func(self, *args, **kwds)
#      33 finally:
#      34     setattr(self, name, False)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pyobjects.py:203, in PyDefinedObject._get_concluded_attributes(self)
#     201 if self.concluded_attributes.get() is None:
#     202     self._get_structural_attributes()
# --> 203     self.concluded_attributes.set(self._create_concluded_attributes())
#     204 return self.concluded_attributes.get()
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/utils/__init__.py:32, in prevent_recursion.<locals>.decorator.<locals>.newfunc(self, *args, **kwds)
#      30 setattr(self, name, True)
#      31 try:
# ---> 32     return func(self, *args, **kwds)
#      33 finally:
#      34     setattr(self, name, False)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pyobjectsdef.py:211, in PyModule._create_concluded_attributes(self)
#     209 result = {}
#     210 for star_import in self.star_imports:
# --> 211     result.update(star_import.get_names())
#     212 return result
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pyobjectsdef.py:667, in StarImport.get_names(self)
#     665 result = {}
#     666 imported = self.imported_module.get_object()
# --> 667 for name in imported:
#     668     if not name.startswith("_"):
#     669         result[name] = pynamesdef.ImportedName(self.imported_module, name)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pyobjects.py:67, in PyObject.__iter__(self)
#      65 def __iter__(self):
#      66     """The same as ``iter(self.get_attributes())``"""
# ---> 67     return iter(self.get_attributes())
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pyobjects.py:208, in PyDefinedObject.get_attributes(self)
#     206 def get_attributes(self):
#     207     if self.attributes.get() is None:
# --> 208         result = dict(self._get_concluded_attributes())
#     209         result.update(self._get_structural_attributes())
#     210         self.attributes.set(result)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/utils/__init__.py:32, in prevent_recursion.<locals>.decorator.<locals>.newfunc(self, *args, **kwds)
#      30 setattr(self, name, True)
#      31 try:
# ---> 32     return func(self, *args, **kwds)
#      33 finally:
#      34     setattr(self, name, False)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pyobjects.py:203, in PyDefinedObject._get_concluded_attributes(self)
#     201 if self.concluded_attributes.get() is None:
#     202     self._get_structural_attributes()
# --> 203     self.concluded_attributes.set(self._create_concluded_attributes())
#     204 return self.concluded_attributes.get()
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/utils/__init__.py:32, in prevent_recursion.<locals>.decorator.<locals>.newfunc(self, *args, **kwds)
#      30 setattr(self, name, True)
#      31 try:
# ---> 32     return func(self, *args, **kwds)
#      33 finally:
#      34     setattr(self, name, False)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pyobjectsdef.py:211, in PyModule._create_concluded_attributes(self)
#     209 result = {}
#     210 for star_import in self.star_imports:
# --> 211     result.update(star_import.get_names())
#     212 return result
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pyobjectsdef.py:666, in StarImport.get_names(self)
#     664 def get_names(self):
#     665     result = {}
# --> 666     imported = self.imported_module.get_object()
#     667     for name in imported:
#     668         if not name.startswith("_"):
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pynames.py:154, in ImportedModule.get_object(self)
#     153 def get_object(self):
# --> 154     if self._get_pymodule() is None:
#     155         return rope.base.pyobjects.get_unknown()
#     156     return self._get_pymodule()
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pynames.py:145, in ImportedModule._get_pymodule(self)
#     141         pymodule = pycore.project.get_module(
#     142             self.module_name, self._current_folder()
#     143         )
#     144     else:
# --> 145         pymodule = pycore.project.get_relative_module(
#     146             self.module_name, self._current_folder(), self.level
#     147         )
#     148     self.pymodule.set(pymodule)
#     149 except exceptions.ModuleNotFoundError:
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/project.py:142, in _Project.get_relative_module(self, name, folder, level)
#     140 if module is None:
#     141     raise ModuleNotFoundError("Module %s not found" % name)
# --> 142 return self.pycore.resource_to_pyobject(module)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pycore.py:135, in PyCore.resource_to_pyobject(self, resource, force_errors)
#     134 def resource_to_pyobject(self, resource, force_errors=False):
# --> 135     return self.module_cache.get_pymodule(resource, force_errors)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pycore.py:256, in _ModuleCache.get_pymodule(self, resource, force_errors)
#     250     result = pyobjectsdef.PyPackage(
#     251         self.pycore,
#     252         resource,
#     253         force_errors=force_errors,
#     254     )
#     255 else:
# --> 256     result = pyobjectsdef.PyModule(
#     257         self.pycore,
#     258         resource=resource,
#     259         force_errors=force_errors,
#     260     )
#     261     if result.has_errors:
#     262         return result
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pyobjectsdef.py:173, in PyModule.__init__(self, pycore, source, resource, force_errors)
#     171 self.has_errors = False
#     172 try:
# --> 173     source, node = self._init_source(pycore, source, resource)
#     174 except exceptions.ModuleSyntaxError:
#     175     self.has_errors = True
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/pyobjectsdef.py:200, in PyModule._init_source(self, pycore, source_code, resource)
#     198         else:
#     199             source_bytes = source_code
# --> 200     ast_node = ast.parse(source_bytes, filename=filename)
#     201 except SyntaxError as e:
#     202     raise exceptions.ModuleSyntaxError(filename, e.lineno, e.msg)
#
# File ~/.cache/pypoetry/virtualenvs/sweepai-u_CIt3kb-py3.10/lib/python3.10/site-packages/rope/base/ast.py:33, in parse(source, filename, *args, **kwargs)
#      31     source += b"\n"
#      32 try:
# ---> 33     return ast.parse(source, filename=filename, *args, **kwargs)
#      34 except (TypeError, ValueError) as e:
#      35     error = SyntaxError()
#
# File /usr/lib/python3.10/ast.py:50, in parse(source, filename, mode, type_comments, feature_version)
#      48     feature_version = -1
#      49 # Else it should be an int giving the minor version for 3.x.
# ---> 50 return compile(source, filename, mode, flags,
#      51                _feature_version=feature_version)
#
# KeyboardInterrupt:

# %%
def move_function(
    file_path: str,
    method_name: str,
    destination: str,
    project_name: str = "src" 
):
    myproject = rope.base.project.Project(project_name)

    myresource = myproject.get_resource(file_path)
    func_def = f"def {method_name}("
    offset = myresource.read().find(func_def) + len("def ")
    print(offset)

    mover = MoveGlobal(myproject, myresource, offset)
    change_set = mover.get_changes(destination)
    for change in change_set.changes:
        print(change.get_description())

move_function("helpers/test2.py", "foo", "utils")
# Out:
# 99
# --- a/helpers/utils.py
# +++ b/helpers/utils.py
# @@ -0,0 +1,5 @@
# +import math
# +
# +
# +def foo():
# +    return math.pow(2, 2)
#
# --- a/helpers/test2.py
# +++ b/helpers/test2.py
# @@ -1,11 +1,8 @@
# -import math
# -
# +import utils
#  def a_func():
#      a = 1
#      b = 2 * a
# -    c = a * foo() + b * 3
# +    c = a * utils.foo() + b * 3
#      print(b, c)
#
#
# -def foo():
# -    return math.pow(2, 2)
